# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Tokenización de textos
#
# En este taller podrán poner en práctica sus conocimientos sobre preprocesamiento de texto (tokenización). El taller está constituido por 5 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos detección de toxicidad en comentarios
#
# En este taller se usará el conjunto de datos de detección de toxicidad en comentarios de la base de datos de Kaggle. Cada observación es un comentario que tiene como variable objetivo (target) la probabilidad de ser un comentario tóxico. El objetivo es predecir la toxicidad de cada comentario. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/c/jigsaw-unintended-bias-in-toxicity-classification/data).

# %%
# SUGERIDO: Descomenta la siguiente linea de código si requieres instalar las libreías básicas utilizadas en este notebook
# Si requieres incluir más librerías puedes agregarlas al archivo Semana 4\requirements.txt
# !pip install -r requirements.txt

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import re
import nltk
from nltk.tokenize import WordPunctTokenizer
from nltk.corpus import stopwords
import pandas as pd
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import mean_squared_error
from sklearn.ensemble import RandomForestRegressor
from matplotlib import pyplot as plt

# %matplotlib inline

# %%
sw = stopwords.words("english")
wpt=WordPunctTokenizer()

# %%
# Carga de datos de archivos .csv
df = pd.read_csv('https://raw.githubusercontent.com/davidzarruk/MIAD_ML_NLP_2025/main/datasets/Toxicity.zip')
df = df[['id','comment_text', 'target']]
df.head()
# Out:
#         id                                       comment_text  target
# 0  6101457  What are you talking about? What group do Pete...     0.0
# 1  5342103   NO!, Let him, we need a Conservative government.     0.0
# 2   743361  Perhaps he took the "power out of the Cardinal...     0.2
# 3   551008  As always, yours is dripping with sarcasm, whi...     0.0
# 4   865998  The dirty little secret is that the price rang...     0.3

# %%
df.shape
# Out:
# (541462, 3)

# %%
# Impresión histograma de variable de interés (y)
df.target.hist()
plt.show()

# %%
# Separación de variable de interés (y)
y = df.target
y.describe()
# Out:
# count    541462.000000
# mean          0.102991
# std           0.196979
# min           0.000000
# 25%           0.000000
# 50%           0.000000
# 75%           0.166667
# max           1.000000
# Name: target, dtype: float64

# %%
# Separación de variables predictoras (X), solo se considera el texto de la noticia
X = df.comment_text

# %%
# Separación de datos en set de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# %% [markdown]
# ## Punto 1 - Tokenización con CountVectorizer
#
# En la celda 1 creen y entrenen el modelo de regresión de su preferencia, para que prediga la probabilidad de que un comentario sea tóxico, usando los set de entrenamiento y test definidos anteriormente. Usen la función **CountVectorizer** para preprocesar los comentarios y presenten el desempeño del modelo con la métrica del MSE.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 1
vect_1 = CountVectorizer()
X_dtm_1 = vect_1.fit_transform(X_train)
X_dtm_1_test = vect_1.transform(X_test)
vect_1.vocabulary_
# Out:
# {'oral': 91127,
#  'history': 60749,
#  'is': 67439,
#  'what': 136457,
#  'ever': 46583,
#  'they': 125107,
#  'say': 110750,
#  'it': 67682,
#  'nazis': 86202,
#  'in': 64454,
#  'the': 124581,
#  '1930': 1649,
#  'did': 38596,
#  'eugenic': 46371,
#  'experiments': 47347,
#  'on': 90518,
#  'native': 86035,
#  'children': 27384,
#  'at': 14725,
#  'mcgill': 80014,
#  'with': 137734,
#  'full': 52599,
#  'knowledge': 71877,
#  'of': 89814,
#  'government': 55832,
#  'yup': 139920,
#  'if': 63495,
#  'happened': 58373,
#  'who': 136894,
#  'are': 13363,
#  'we': 135729,
#  'to': 126248,
#  'didn': 38619,
#  'marijuana': 78894,
#  'less': 74583,
#  'harmful': 58542,
#  'human': 62386,
#  'health': 59284,
#  'than': 124498,
#  'cigarettes': 28085,
#  'which': 136645,
#  'widely': 137099,
#  'used': 132446,
#  'and': 11703,
#  'there': 124961,
#  'no': 87715,
#  'ban': 16514,
#  'reduces': 104654,
#  'stress': 120277,
#  'aggression': 9490,
#  'level': 74674,
#  'leading': 73899,
#  'crime': 33788,
#  'its': 67777,
#  'medical': 80457,
#  'value': 132943,
#  'favorable': 48684,
#  'effects': 43479,
#  'scientifically': 111467,
#  'proven': 100853,
#  'author': 15271,
#  'also': 10907,
#  'should': 114183,
#  'have': 58899,
#  'consideration': 31529,
#  'that': 124538,
#  'use': 132443,
#  'legalized': 74231,
#  'market': 78985,
#  'will': 137329,
#  'be': 17506,
#  'transparent': 127467,
#  'surely': 121765,
#  'better': 18749,
#  'illegal': 63731,
#  'sales': 109974,
#  'this': 125257,
#  'drug': 41832,
#  'these': 125054,
#  'cases': 25359,
#  'young': 139737,
#  'adult': 8890,
#  'interest': 66490,
#  'more': 83853,
#  'drugs': 41848,
#  'hence': 59818,
#  'need': 86439,
#  'as': 14164,
#  'cannot': 24634,
#  'cause': 25759,
#  'problems': 100025,
#  'bigger': 19062,
#  'widespread': 137111,
#  'do': 40418,
#  'look': 76377,
#  'see': 112274,
#  'how': 62031,
#  'many': 78686,
#  'women': 138013,
#  'photos': 96160,
#  'white': 136785,
#  'supremecists': 121721,
#  'were': 136206,
#  'all': 10584,
#  'other': 91682,
#  'side': 114524,
#  'like': 75253,
#  'others': 91696,
#  'stood': 119944,
#  'up': 132070,
#  'south': 117496,
#  'africa': 9304,
#  'years': 139396,
#  'ago': 9551,
#  'you': 139715,
#  'not': 88357,
#  'agree': 9582,
#  'shame': 113329,
#  'next': 87139,
#  'll': 75884,
#  'coming': 30055,
#  'for': 51084,
#  'isis': 67497,
#  'could': 32896,
#  'left': 74157,
#  'was': 135386,
#  'great': 56313,
#  'act': 8337,
#  'nepotism': 86710,
#  'get': 54273,
#  'charles': 26781,
#  'old': 90235,
#  'time': 125892,
#  'alaskans': 10238,
#  'from': 52279,
#  'good': 55465,
#  'families': 48298,
#  'ones': 90574,
#  'blew': 19956,
#  'through': 125510,
#  'vast': 133151,
#  'amounts': 11422,
#  'oil': 90083,
#  'wealth': 135756,
#  'instead': 66154,
#  'creating': 33604,
#  'sovereign': 117552,
#  'fund': 52664,
#  'norwegian': 88304,
#  'now': 88551,
#  'steal': 119328,
#  'pfd': 95770,
#  'poor': 98088,
#  'so': 116673,
#  'don': 40798,
#  'pay': 94356,
#  'taxes': 123485,
#  'your': 139757,
#  'fluff': 50664,
#  'piece': 96355,
#  'doesn': 40549,
#  'conceal': 30763,
#  'any': 12489,
#  'just': 69707,
#  'gonna': 55443,
#  'my': 85265,
#  'logic': 76180,
#  'teacher': 123636,
#  'would': 138392,
#  'give': 54759,
#  'zero': 140192,
#  'obvious': 89543,
#  'generally': 53924,
#  'speaking': 117773,
#  'competent': 30481,
#  'shooter': 114065,
#  'gun': 57268,
#  'has': 58702,
#  'ability': 7547,
#  'rapidly': 103285,
#  'shoot': 114062,
#  'multiple': 84810,
#  'rounds': 108773,
#  'gives': 54773,
#  'advantage': 8929,
#  'over': 92136,
#  'anyone': 12506,
#  'similar': 114851,
#  'skill': 115391,
#  'similarly': 114856,
#  'armed': 13563,
#  'gop': 55600,
#  'had': 57722,
#  'opportunity': 90997,
#  'nominate': 87881,
#  'gov': 55787,
#  'kasich': 70382,
#  'presidential': 99448,
#  'candidate': 24539,
#  'he': 59166,
#  'been': 17856,
#  'nominated': 87882,
#  'likely': 75267,
#  'our': 91793,
#  'president': 99442,
#  'republican': 106216,
#  'party': 93923,
#  'dominated': 40758,
#  'by': 23660,
#  'far': 48404,
#  'right': 107598,
#  'zealots': 140124,
#  'chose': 27722,
#  'donald': 40807,
#  'trump': 128343,
#  'sort': 117366,
#  'thing': 125191,
#  'happens': 58379,
#  'when': 136586,
#  're': 103683,
#  'willing': 137374,
#  'sell': 112496,
#  'out': 91829,
#  'political': 97753,
#  'principles': 99805,
#  'gain': 53083,
#  'power': 98692,
#  '2010': 1981,
#  'controlled': 32072,
#  'those': 125377,
#  'rinos': 107758,
#  'represented': 106119,
#  'sensible': 112680,
#  'rational': 103446,
#  'center': 26191,
#  'moderate': 83102,
#  'republicans': 106222,
#  'gone': 55426,
#  'defeated': 36468,
#  'primaries': 99744,
#  'or': 91115,
#  'retired': 106882,
#  'simply': 114920,
#  'ask': 14307,
#  'tens': 124099,
#  'millions': 81982,
#  'mainstream': 77957,
#  'lost': 76577,
#  'their': 124796,
#  'worth': 138360,
#  'around': 13640,
#  'today': 126306,
#  'divided': 40230,
#  'tattered': 123402,
#  'shell': 113658,
#  'yourselves': 139779,
#  'then': 124854,
#  'earth': 42837,
#  'going': 55323,
#  'after': 9347,
#  'defeat': 36466,
#  'join': 69137,
#  'him': 60556,
#  'his': 60704,
#  'accusations': 8093,
#  'election': 43873,
#  'rigged': 107589,
#  'help': 59745,
#  'undermine': 130526,
#  'faith': 48148,
#  'democracy': 37097,
#  'hope': 61635,
#  'chief': 27332,
#  'guessing': 57102,
#  'aware': 15573,
#  'sisyphean': 115146,
#  'task': 123354,
#  'entails': 45237,
#  'failed': 48068,
#  'apologist': 12713,
#  'foregone': 51179,
#  'reason': 103933,
#  'thought': 125392,
#  'order': 91210,
#  'attempt': 14952,
#  'stake': 118900,
#  'position': 98374,
#  'support': 121647,
#  'know': 71864,
#  'trumpery': 128403,
#  'tests': 124353,
#  'daily': 35193,
#  'very': 133579,
#  'bounds': 21276,
#  'itself': 67782,
#  'contort': 31958,
#  'way': 135653,
#  'into': 66787,
#  'attempting': 14955,
#  'defend': 36502,
#  'indefensible': 64939,
#  'guess': 57097,
#  'justin': 69748,
#  'wanted': 135207,
#  'whip': 136725,
#  'cf18': 26369,
#  'clown': 29021,
#  'show': 114224,
#  'yep': 139477,
#  'emotion': 44518,
#  'lies': 75101,
#  'leave': 74022,
#  'democrat': 37106,
#  'socialist': 116743,
#  'judges': 69488,
#  'since': 114955,
#  'best': 18669,
#  'dog': 40562,
#  'spaying': 117748,
#  'neutering': 86896,
#  'before': 17897,
#  'growth': 56824,
#  'plates': 97044,
#  'close': 28950,
#  'contribute': 32041,
#  'joint': 69146,
#  'tendon': 124060,
#  'ligament': 75181,
#  'bone': 20759,
#  'issues': 67653,
#  'why': 137036,
#  'take': 122952,
#  'away': 15578,
#  'hormones': 61723,
#  'develop': 38179,
#  'healthy': 59316,
#  'bodies': 20493,
#  'really': 103850,
#  'care': 25005,
#  'about': 7658,
#  'them': 124824,
#  'monopoly': 83581,
#  'capital': 24778,
#  'established': 46148,
#  'big': 19035,
#  'business': 23378,
#  'degrade': 36708,
#  'entire': 45298,
#  'argument': 13448,
#  'reify': 105193,
#  'myth': 85388,
#  'wmc': 137876,
#  'cynical': 34972,
#  'fabrication': 47882,
#  'unless': 131322,
#  'both': 21171,
#  'adjectives': 8653,
#  'distorted': 40062,
#  'meaninglessness': 80301,
#  'accurate': 8087,
#  'much': 84542,
#  'emotional': 44519,
#  'term': 124161,
#  'credit': 33650,
#  'append': 12835,
#  'but': 23446,
#  'only': 90634,
#  'addition': 8542,
#  'bogeyman': 20550,
#  'single': 114999,
#  'even': 46554,
#  'biggest': 19064,
#  'against': 9395,
#  'equally': 45677,
#  'global': 54962,
#  'competitors': 30499,
#  'public': 101227,
#  'listed': 75660,
#  'companies': 30395,
#  'shares': 113436,
#  'sale': 109963,
#  'buyers': 23569,
#  'races': 102699,
#  'destructive': 37990,
#  'pejorative': 94774,
#  'serving': 112945,
#  'proxy': 100940,
#  'calculated': 24078,
#  'insult': 66254,
#  'abuse': 7810,
#  'people': 95020,
#  'especially': 46067,
#  'wealthy': 135767,
#  'sibling': 114480,
#  'stole': 119886,
#  'land': 73169,
#  'police': 97685,
#  'seek': 112303,
#  'phone': 96092,
#  'records': 104370,
#  'claimed': 28417,
#  'without': 137777,
#  'evidence': 46681,
#  'being': 18036,
#  'example': 46849,
#  'witness': 137795,
#  'claim': 28413,
#  'newspaper': 87077,
#  'wing': 137534,
#  'equates': 45684,
#  'clinton': 28854,
#  'sexual': 113109,
#  'escapades': 45982,
#  'trumps': 128552,
#  'nope': 88157,
#  'decry': 36358,
#  'acts': 8395,
#  'themselves': 124844,
#  'decried': 36344,
#  'inconsistency': 64800,
#  'treated': 127677,
#  'dnc': 40399,
#  'press': 99475,
#  'largely': 73356,
#  'proved': 100852,
#  'disproved': 39852,
#  'two': 129388,
#  'major': 78025,
#  'differences': 38692,
#  'excuse': 47036,
#  'yes': 139488,
#  'leftist': 74176,
#  'ignored': 63593,
#  'hillary': 60489,
#  'accusers': 8102,
#  'threatened': 125440,
#  'keep': 70660,
#  'silent': 114761,
#  'subpoenaed': 120811,
#  'impeached': 64135,
#  'lying': 77227,
#  'deeds': 36395,
#  'every': 46622,
#  'victim': 133772,
#  'come': 29987,
#  'forward': 51486,
#  'last': 73441,
#  'months': 83658,
#  'convenient': 32119,
#  'dropped': 41784,
#  'case': 25351,
#  'via': 133693,
#  'own': 92631,
#  'lawyers': 73730,
#  'suppose': 121665,
#  'believe': 18122,
#  'traitor': 127247,
#  'snowden': 116586,
#  'exist': 47172,
#  'though': 125388,
#  'hiding': 60299,
#  'russia': 109312,
#  'heh': 59544,
#  'watch': 135495,
#  'sid': 114516,
#  'here': 59945,
#  'trolls': 128117,
#  'primitivepagan': 99773,
#  'buffalo': 22735,
#  'nickel': 87290,
#  'statue': 119251,
#  'one': 90546,
#  'profile': 100204,
#  'nearly': 86341,
#  'made': 77612,
#  'extinct': 47579,
#  'exactly': 46813,
#  'thoughts': 125405,
#  'ridiculous': 107518,
#  'media': 80416,
#  'content': 31863,
#  'bash': 17061,
#  'sa': 109558,
#  'ap': 12568,
#  'alike': 10530,
#  'singing': 114998,
#  'lumberjack': 77000,
#  'ok': 90156,
#  'relevance': 105458,
#  'topic': 126663,
#  'another': 12166,
#  'cover': 33182,
#  'justify': 69743,
#  'comments': 30151,
#  'wiretapped': 137659,
#  'under': 130437,
#  'surveillance': 121884,
#  'saw': 110721,
#  'conference': 31055,
#  'certainly': 26304,
#  'pass': 93963,
#  'smell': 116128,
#  'test': 124312,
#  'spiecer': 118045,
#  'words': 138191,
#  'appeared': 12811,
#  'got': 55710,
#  'caught': 25736,
#  'pants': 93370,
#  'down': 41269,
#  'administration': 8724,
#  'destroying': 37979,
#  'makes': 78076,
#  'mind': 82070,
#  'drift': 41667,
#  'back': 15981,
#  'west': 136241,
#  'berrendo': 18591,
#  'road': 107983,
#  'north': 88243,
#  'roswell': 108664,
#  'mex': 81373,
#  '30': 3201,
#  'lived': 75810,
#  'almost': 10811,
#  'dreams': 41590,
#  'took': 126593,
#  'place': 96889,
#  'house': 61957,
#  'undersheriff': 130586,
#  'egg': 43558,
#  'farm': 48447,
#  'toward': 126974,
#  'town': 126992,
#  'redneck': 104601,
#  'kid': 71182,
#  'always': 11025,
#  'mowed': 84333,
#  'mail': 77898,
#  'boxes': 21368,
#  'home': 61255,
#  'dune': 42326,
#  'buggy': 22791,
#  'till': 125836,
#  'dad': 35132,
#  'erected': 45788,
#  'cement': 26148,
#  'filled': 49664,
#  'drill': 41679,
#  'pipe': 96665,
#  'tank': 123167,
#  'mile': 81832,
#  'behind': 18004,
#  'where': 136602,
#  'sneak': 116389,
#  'bank': 16617,
#  'sluice': 115985,
#  'ducks': 42062,
#  'shot': 114166,
#  '20': 1923,
#  'guage': 56981,
#  've': 133239,
#  'driven': 41725,
#  'never': 86921,
#  'stopped': 119975,
#  'gravel': 56235,
#  'paved': 94321,
#  'box': 21359,
#  'street': 120237,
#  'number': 88821,
#  'route': 108799,
#  'houses': 61994,
#  'springing': 118432,
#  'wonder': 138031,
#  'still': 119714,
#  'well': 136118,
#  'sandys': 110302,
#  'cuz': 34856,
#  'remember': 105624,
#  'pig': 96400,
#  'across': 8325,
#  'country': 33049,
#  'can': 24404,
#  'go': 55155,
#  'lidda': 75062,
#  'bit': 19532,
#  'moa': 83004,
#  'da': 35094,
#  'real': 103781,
#  'ahupua': 9760,
#  'waimanalo': 134950,
#  'hk': 60846,
#  'part': 93812,
#  'nalo': 85683,
#  'getting': 54306,
#  'gentrified': 54047,
#  'mean': 80281,
#  'harvested': 58692,
#  'planny': 96993,
#  'lobster': 76036,
#  'off': 89834,
#  'makapu': 78054,
#  'too': 126581,
#  'days': 35728,
#  'heard': 59329,
#  'minorities': 82221,
#  'introducing': 66867,
#  'islamic': 67512,
#  'prayers': 98904,
#  'ontario': 90674,
#  'schools': 111349,
#  'mr': 84390,
#  'lesson': 74598,
#  'canada': 24414,
#  'kaneshiro': 70217,
#  'again': 9391,
#  'henry': 59869,
#  'tsk': 128754,
#  'saullie': 110638,
#  'astute': 14700,
#  'price': 99674,
#  'playing': 97109,
#  'somewhere': 117164,
#  'else': 44160,
#  'year': 139375,
#  'staying': 119295,
#  'team': 123655,
#  'perhaps': 95190,
#  'couple': 33073,
#  'players': 97100,
#  'short': 114119,
#  'winning': 137591,
#  'admitted': 8770,
#  'phony': 96114,
#  'according': 8010,
#  'us': 132367,
#  'news': 87013,
#  'reports': 106074,
#  'whittling': 136878,
#  'stick': 119647,
#  'opening': 90848,
#  'letter': 74638,
#  'neither': 86599,
#  'scenarios': 111064,
#  'forceful': 51123,
#  'engagement': 44985,
#  'sure': 121761,
#  'might': 81735,
#  'put': 101731,
#  'questions': 102320,
#  'wouldn': 138398,
#  'imagine': 63858,
#  'unsnapping': 131792,
#  'holsters': 61225,
#  'either': 43731,
#  'allie': 10673,
#  'same': 110126,
#  'question': 102306,
#  'doing': 40649,
#  'nothing': 88414,
#  'hasn': 58746,
#  'produced': 100122,
#  'anything': 12518,
#  'ignore': 63592,
#  'scudd': 111822,
#  'attack': 14925,
#  'kathleen': 70438,
#  'intentions': 66404,
#  'spiteful': 118146,
#  'yet': 139520,
#  'her': 59898,
#  'persistence': 95432,
#  'knew': 71798,
#  'revolutionary': 107165,
#  'she': 113546,
#  'lo': 75971,
#  'behold': 18011,
#  'energy': 44927,
#  'green': 56357,
#  'thanks': 124518,
#  'must': 85138,
#  'kill': 71271,
#  'conservatism': 31490,
#  'national': 85987,
#  'scale': 110882,
#  'mit': 82765,
#  'merely': 81037,
#  'said': 109862,
#  'responsible': 106647,
#  'impossible': 64305,
#  'assad': 14394,
#  'done': 40848,
#  'opcw': 90829,
#  'reported': 106063,
#  '2013': 1999,
#  'syria': 122605,
#  'large': 73353,
#  'amount': 11419,
#  'precursors': 99024,
#  'sarin': 110466,
#  'binary': 19273,
#  'form': 51331,
#  'agent': 9444,
#  'mixed': 82820,
#  'shelf': 113652,
#  'life': 75113,
#  'because': 17715,
#  'main': 77928,
#  'stored': 119990,
#  'separately': 112756,
#  'stability': 118801,
#  'prior': 99833,
#  'bombing': 20727,
#  'explosion': 47425,
#  'destroyed': 37973,
#  'isopropyl': 67600,
#  'alcohol': 10358,
#  'cloud': 28992,
#  'fire': 49878,
#  'furthermore': 52803,
#  'blowing': 20197,
#  'together': 126362,
#  'does': 40547,
#  'result': 106775,
#  'nerve': 86733,
#  'chemically': 27131,
#  'presuming': 99531,
#  'unitary': 131196,
#  'rebels': 104014,
#  'acquire': 8286,
#  'afford': 9215,
#  'technology': 123741,
#  'expertise': 47355,
#  'produce': 100120,
#  'saying': 110760,
#  'chemical': 27128,
#  'weapons': 135789,
#  'somehow': 117122,
#  'seem': 112315,
#  'forces': 51127,
#  'nobody': 87754,
#  'went': 136189,
#  'broke': 22253,
#  'underestimating': 130485,
#  'taste': 123369,
#  'american': 11229,
#  'worrying': 138332,
#  'name': 85700,
#  'try': 128689,
#  'producing': 100126,
#  'decent': 36138,
#  'beer': 17865,
#  'america': 11225,
#  'small': 116041,
#  'brewery': 21944,
#  'drink': 41688,
#  'locals': 76061,
#  'drinking': 41696,
#  'want': 135200,
#  'otherwise': 91699,
#  'repeal': 105928,
#  'obamacare': 89211,
#  'outright': 92023,
#  'replace': 105994,
#  'free': 51916,
#  'lot': 76578,
#  'legislation': 74298,
#  'undermines': 130529,
#  'remove': 105701,
#  'tax': 123460,
#  'provided': 100866,
#  'incentives': 64637,
#  'employer': 44601,
#  'insurance': 66267,
#  'comprehensive': 30653,
#  'reform': 104863,
#  'combines': 29963,
#  'fewer': 49369,
#  'deductions': 36387,
#  'lower': 76721,
#  'rates': 103417,
#  'allows': 10746,
#  'congress': 31254,
#  'birds': 19438,
#  'stone': 119915,
#  'peter': 95617,
#  'schiff': 111161,
#  '2017': 2037,
#  '06': 182,
#  '23': 2546,
#  'word': 138180,
#  'citizen': 28272,
#  'united': 131200,
#  'states': 119184,
#  'muslim': 85097,
#  'an': 11518,
#  'previous': 99629,
#  'article': 13802,
#  '18': 1429,
#  'somalia': 117098,
#  'permanent': 95272,
#  'status': 119259,
#  'recent': 104138,
#  'meeting': 80579,
#  'democratic': 37109,
#  'socialists': 116747,
#  'taking': 122981,
#  'bds': 17500,
#  'bill': 19183,
#  'chants': 26650,
#  'palestine': 93128,
#  'river': 107877,
#  'sea': 111909,
#  'pushing': 101698,
#  'israeli': 67616,
#  'affirmed': 9194,
#  'goal': 55164,
#  'think': 125203,
#  'named': 85705,
#  'person': 95443,
#  'perfect': 95139,
#  'above': 7668,
#  'reproach': 106155,
#  'some': 117111,
#  'bad': 16136,
#  'someone': 117131,
#  'offense': 89858,
#  'point': 97577,
#  'badger': 16158,
#  'redeemed': 104504,
#  'himself': 60570,
#  'enough': 45140,
#  'earned': 42814,
#  'respect': 106588,
#  'community': 30338,
#  'once': 90532,
#  'fallen': 48217,
#  'grace': 55933,
#  'minds': 82094,
#  'change': 26607,
#  '1940s': 1665,
#  'sins': 115052,
#  'forgivable': 51301,
#  '2010s': 1986,
#  'criteria': 33899,
#  'safe': 109774,
#  'therefore': 124978,
#  'idea': 63257,
#  'corrupt': 32683,
#  'sick': 114495,
#  'vote': 134502,
#  'hill': 60475,
#  'larious': 73370,
#  'confused': 31190,
#  'soul': 117419,
#  'tell': 123932,
#  'honest': 61446,
#  'fake': 48164,
#  'flake': 50209,
#  'anymore': 12503,
#  'indeed': 64931,
#  'sad': 109700,
#  'beaten': 17621,
#  'seems': 112321,
#  'lowest': 76730,
#  'common': 30268,
#  'denominator': 37328,
#  'liberal': 74884,
#  'progressives': 100300,
#  'wanting': 135209,
#  'reality': 103828,
#  'congenital': 31209,
#  'duplicitous': 42401,
#  'liar': 74843,
#  'dems': 37236,
#  'downtrodden': 41354,
#  'facts': 48002,
#  'prove': 100850,
#  'herself': 60061,
#  'able': 7569,
#  'convince': 32204,
#  'emotionally': 44524,
#  'laughs': 73561,
#  'evil': 46692,
#  'laugh': 73548,
#  'wiki': 137218,
#  'encyclopedia': 44800,
#  'reliable': 105467,
#  'source': 117467,
#  'general': 53896,
#  'information': 65517,
#  'citation': 28250,
#  'collection': 29692,
#  'useful': 132449,
#  'reference': 104775,
#  'material': 79428,
#  'quoted': 102497,
#  'directly': 39114,
#  'such': 121027,
#  'isn': 67576,
#  'wrong': 138580,
#  'student': 120476,
#  'cited': 28254,
#  'articles': 14078,
#  'cites': 28257,
#  'immigrant': 64012,
#  'committed': 30237,
#  'violent': 134062,
#  'absolutely': 7736,
#  'criminal': 33807,
#  'needs': 86455,
#  'face': 47899,
#  'consequences': 31457,
#  'larger': 73359,
#  'problem': 100016,
#  'vision': 134144,
#  'immigration': 64020,
#  'fear': 48822,
#  'nice': 87269,
#  'lady': 72922,
#  'whom': 136940,
#  'lucky': 76913,
#  'teach': 123633,
#  'ccd': 25911,
#  'card': 24967,
#  'holder': 61110,
#  'fearful': 48826,
#  'future': 52852,
#  'breaking': 21768,
#  'law': 73666,
#  'miserably': 82448,
#  'reassure': 103966,
#  'fault': 48648,
#  'hers': 60057,
#  'powerful': 98701,
#  'friend': 52160,
#  'powerless': 98709,
#  'works': 138257,
#  'me': 80260,
#  'step': 119482,
#  'ah': 9644,
#  'pious': 96660,
#  'mouthing': 84298,
#  'protected': 100755,
#  'canadians': 24461,
#  'annie2013': 12052,
#  'prefer': 99154,
#  'door': 40994,
#  'visit': 134152,
#  'unimpeded': 131112,
#  'snow': 116568,
#  'flies': 50441,
#  'products': 100139,
#  'services': 112939,
#  'find': 49766,
#  'customer': 34807,
#  'military': 81890,
#  'keeps': 70670,
#  'hot': 61880,
#  'tub': 128832,
#  'yourself': 139775,
#  'annie': 12051,
#  'company': 30402,
#  'prediction': 99075,
#  'forced': 51119,
#  'diversity': 40209,
#  'initiatives': 65753,
#  'turn': 129089,
#  'forcing': 51133,
#  'students': 120478,
#  'school': 111325,
#  'educate': 43348,
#  'intention': 66398,
#  'intent': 66396,
#  'social': 116728,
#  'justice': 69725,
#  'making': 78094,
#  'everyone': 46639,
#  'illiterate': 63778,
#  'shown': 114253,
#  'connection': 31338,
#  'between': 18776,
#  '47': 4136,
#  'murders': 84963,
#  'suspicious': 121957,
#  'suicides': 121173,
#  'proof': 100477,
#  'hahaha': 57799,
#  'let': 74610,
#  'putin': 101744,
#  'commit': 30223,
#  'doubt': 41176,
#  'killings': 71288,
#  'probable': 99977,
#  'speech': 117883,
#  'sacred': 109665,
#  'trust': 128630,
#  'include': 64716,
#  'knowingly': 71871,
#  'lie': 75071,
#  ...}

# %%
X_dtm_1.shape
# Out:
# (362779, 141176)

# %% [markdown]
# La matriz resultante presenta dimensiones excesivas para ser procesadas en equipos convencionales. Para poder avanzar en los objetivos de este taller, se adoptarán las siguientes medidas:
#
# 1. **Reducción de muestra:** selección de un subconjunto representativo de forma aleatoria
# 2. **Limpieza de texto:** eliminación de stopwords con el fin de reducir términos de escaso valor para el modelo.
# 3. **Hiperparametros:** Modificación de los hiperparametros en numero de árboles y máxima profunidad

# %%
df_sample = df.sample(frac=0.05, random_state=42)  # 5% aleatorio
df_sample.head(10)
# Out:
#              id                                       comment_text    target
# 356574  5286156  Interesting ! Sorry to hear of a small busines...  0.000000
# 471747  5468307  I will take that into consideration, Motley. I...  0.000000
# 118328  5352425  I guess after having a somewhat positive portr...  0.000000
# 142944   353614  According to leading Public Finance and Enviro...  0.000000
# 496670  6265464  Great. What were you ever even thinking? Now y...  0.000000
# 278954   708156  That is absolute bull crap. You poke the bear ...  0.800000
# 129015  5190282  Personally I will not listen to Pro-Abortionis...  0.000000
# 27042   6262712  I'm not one to think that highly of people in ...  0.166667
# 308533  5949396  I don't think so.\nThe turning point of the el...  0.200000
# 180558  5327560  When reading the article, it seems to say that...  0.000000

# %%
df_sample.shape
# Out:
# (27073, 3)

# %%
def preprocess_and_clean(doc: str) -> str:
    doc = re.sub(r"[áÁ]", "a", doc)
    doc = re.sub(r"[éÉ]", "e", doc)
    doc = re.sub(r"[íÍ]", "i", doc)
    doc = re.sub(r"[óÓ]", "o", doc)
    doc = re.sub(r"[úÚ]", "u", doc)
    doc = re.sub(r"[^a-zA-Z\s]", " ", doc)
    doc = doc.lower()

    # 4) Tokeniza y filtra:
    #    - tokens de al menos 2 caracteres
    #    - tokens que no estén en sw
    tokens = [
        tok for tok in wpt.tokenize(doc)
        if len(tok) >= 2 and tok not in sw
    ]

    # 5) Reconstruye el texto; si queda vacío, etiqueta como "empty"
    cleaned = " ".join(tokens)
    return cleaned if cleaned.strip() else "empty"

# %%
max_depth = 5
n_estimators = 100

# %%
# Modelo sin preprocesamiento de la información
X = df_sample.comment_text      
y = df_sample.target     
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
vect_raw = CountVectorizer()
X_train_dtm = vect_raw.fit_transform(X_train)
X_test_dtm  = vect_raw.transform(X_test)

rf_raw = RandomForestRegressor(n_estimators=n_estimators,random_state=42,max_depth=max_depth)
rf_raw.fit(X_train_dtm, y_train)
y_pred_raw = rf_raw.predict(X_test_dtm)
mse_raw = mean_squared_error(y_test, y_pred_raw)
mse_raw
# Out:
# 0.030998129306051045

# %% [markdown]
# A continuación aplicaremos el preprocesamiento a la columna "comment_text"

# %%
df_sample["comment_text_cleaned"] = df_sample["comment_text"].apply(preprocess_and_clean)

# %%
# Separación de variables predictoras (X), solo se considera el texto de la noticia
X = df_sample.comment_text_cleaned
# Separación de variable de interés (y)
y = df_sample.target
# Separación de datos en set de entrenamiento y test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)
# CountVectorizer
vect_clean = CountVectorizer()
X_train_dtm_clean = vect_clean.fit_transform(X_train)
X_test_dtm_clean = vect_clean.transform(X_test)
print(X_train_dtm_clean.shape)
# Modelo con preprocesamiento de la información
rf_clean = RandomForestRegressor(n_estimators=n_estimators, random_state=42, max_depth=max_depth)
rf_clean.fit(X_train_dtm_clean, y_train)
y_pred_clean = rf_clean.predict(X_test_dtm_clean)
mse_clean = mean_squared_error(y_test, y_pred_clean)
mse_clean
# Out:
# (18138, 34605)
# 0.0311612247454276

# %% [markdown]
# Con la depueración mencionada anteriormente se pudo bajar de 141.176 a 34.605 las columnas de la matriz del CountVectorizer. Con esto, se espera poder ejecutar los modelores de regresión con máquinas convencionales.

# %% [markdown]
# ## Punto 2 - Tokenización con CountVectorizer y trigramas
#
# En la celda 2 creen y entrenen el mismo modelo de regresión del punto anterior (es decir si usaron un RandomForestRegresor usen nuevamente ese regresor), para que prediga la probabilidad de que un comentario sea tóxico, usando los set de entrenamiento y test definidos anteriormente. Usen la función CountVectorizer **considerando trigramas** para preprocesar los comentarios y presenten el desempeño del modelo con la métrica del MSE.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# CountVectorizer con trigrams
vect_tri = CountVectorizer(ngram_range=(3, 3))
X_train_dtm_tri = vect_tri.fit_transform(X_train)
X_test_dtm_tri  = vect_tri.transform(X_test)
print(X_train_dtm_tri.shape)

# Modelo con trigrams
rf_tri = RandomForestRegressor(n_estimators=n_estimators, random_state=42, max_depth=max_depth)
rf_tri.fit(X_train_dtm_tri, y_train)
y_pred_tri = rf_tri.predict(X_test_dtm_tri)
mse_tri = mean_squared_error(y_test, y_pred_tri)
mse_tri
# Out:
# (18138, 439708)
# 0.03732486941576539

# %% [markdown]
# ## Punto 3 - TfidfVectorizer
#
# Investigen sobre la función TfidfVectorizer. En la celda de texto 3, expliquen en qué consiste esta técnica de tokenización (describanla y expliquen su funcionamiento) y cúales son las ventajas o deventajas de su uso al compararlo con la función CountVectorizer.

# %% [markdown]
# ### TF-IDF
#
# Una de las principales desventajas de las bolsas de palabras es que asumen que todos los términos tienen igual importancia. No obstante, existen dos casos en los que algunos términos deberían tener mayor o menor importancia:
#
# 1. Palabras comunes que aparecen en todos los documentos y no aportan mucha información para distinguir un documento de otro.
# 2. Términos únicos y poco frecuentes que son sumamente relevantes para distinguir algunos documentos en específico.
#
# En este ámbito, surge la necesidad de estrategias que permitan capturar este tipo de relaciones. Una de las soluciones más comunes es **term frequency - inverse document frequency (TF-IDF)**. Se trata de un método que fue propuesto como métrica para la evaluación de resultados en motores de búsqueda y se convirtió en un estándar dentro de los sistemas de recuperación de información.
#
# **TF-IDF** amplía la idea de bolsas de palabras al ponderar cada término $t_i$ por un peso $w_{i}$ como se muestra a continuación:
#
# $$
# \text{TFIDF}(t_i | d_j) = \text{TF}(t_i|d_j) \cdot w_i
# $$
#
# Con esto, se puede asignar un peso menor a aquellos términos comunes entre documentos y un peso mayor a aquellos términos poco frecuentes. Una de las formas más comunes para determinar estos pesos es con la **frecuencia inversa de documento** $w_{idf}(t_i)$ que se calcula de la siguiente forma:
#
# $$
# w_i = 1 + \log{\frac{N}{1 + \text{df}(t_i)}}
# $$
#
# Donde $N$ es el número de documentos en el corpus y $\text{df}(t_i)$ es el número de documentos en los que se encuentra el término $t_i$.
#
# Adicionalmente, una extención de TF-IDF consiste en un cambio de escala de la matriz de términos, con esto, se busca atenuar el impacto que tienen los términos que aparecen muchas veces en un documento. Esto se consigue utilizando *sub-linear scaling* $wf(\mathbf{Tf}(t_i,d_j))$ y consiste en transformar las ocurrencias a una escala logarítmica donde los valores grandes se ven atenuados:
#
# $$
# wf(\text{TF}(t_i|d_j)) = \left\{
# \begin{array}{cl}
# 1+\log{\text{TF}(t_i|d_j)}      & \mathrm{si\ } \text{TF}(t_i|d_j) > 0 \\
# 0 & \mathrm{si\ } \text{TF}(t_i|d_j) \le 0 \\
# \end{array}
# \right.
# $$
#
# Finalmente, una versión de TF-IDF con *sub-linear scaling* se muestra a continuación:
#
# $$
# tfidf_{2}(t_i|d_j) = wf(\text{TF}(t_i|d_j)) w_i
# $$
#
# ## Ventajas clave de TF‑IDF vs CountVectorizer
#
# - **Mejor ponderación de los términos**
#   - Evita que palabras muy frecuentes (p.ej. “el”, “de”, “y”).
#   - Da más peso a términos poco frecuentes y potencialmente más informativos.
#
# - **Normalización**
#   - Documentos de distinta longitud pasan a ser comparables.
#
# - **Sub‑linear scaling**
#   - Opcionalmente atenúa el efecto de conteos muy altos, ayudando a mitigar outliers de frecuencia.
#
#
# ## Desventajas de TF‑IDF vs el CountVectorizer
#
# - **Mayor complejidad y coste**
#   - Es necesario hacer todo el BoW para luego hacer la ponderación
#
# - **Difícil actualización incremental**
#   - Con nuevos documentos cambia el IDF global; requiere recalcular para mantener consistencia.
#
# - **Puede sobreponderar términos muy poco frecuentes**
#   - Palabras poco frecuentes pueden recibir peso alto aunque quizá no aporten generalización.

# %%
# Ejemplo
from sklearn.feature_extraction.text import TfidfVectorizer

docs = [
    "Los estudiantes estudian en la biblioteca",
    "En la biblioteca los estudiantes estudian",
    "Estudiantes en la biblioteca estudian",
]

vectorizer = TfidfVectorizer()
tfidf_matrix = vectorizer.fit_transform(docs)

df_tfidf = pd.DataFrame(
    tfidf_matrix.toarray(),
    columns=vectorizer.get_feature_names_out(),
    index=[f"Doc{i+1}" for i in range(len(docs))]
)
df_tfidf
# Out:
#       biblioteca        en  estudian  estudiantes        la       los
# Doc1    0.387547  0.387547  0.387547     0.387547  0.387547  0.499037
# Doc2    0.387547  0.387547  0.387547     0.387547  0.387547  0.499037
# Doc3    0.447214  0.447214  0.447214     0.447214  0.447214  0.000000

# %% [markdown]
# ## Punto 4 - Tokenización con TfidfVectorizer
#
# En la celda 4 creen y entrenen el mismo modelo de regresión del primer punto, para que prediga la probabilidad de que un comentario sea tóxico, usando los set de entrenamiento y test definidos anteriormente. Procesen los comentarios con la función **TfidfVectorizer** y presenten el desempeño del modelo con la métrica del MSE.
#
# Recuerden que el preprocesamiento que se haga sobre los datos de entrenamiento  (*.fit_transform()*) deben ser aplicado al set de test (*.transform()*).

# %%
# Celda 4
# TF‑IDF Vectorizer
tfidf = TfidfVectorizer()
X_train_tfidf = tfidf.fit_transform(X_train)
X_test_tfidf  = tfidf.transform(X_test)
print(X_train_tfidf.shape)

# Modelo con TF‑IDF
rf_tfidf = RandomForestRegressor(n_estimators=n_estimators, random_state=42, max_depth=max_depth)
rf_tfidf.fit(X_train_tfidf, y_train)
y_pred_tfidf = rf_tfidf.predict(X_test_tfidf)
mse_tfidf = mean_squared_error(y_test, y_pred_tfidf)
mse_tfidf
# Out:
# (18138, 34605)
# 0.03096112359489846

# %% [markdown]
# ## Punto 5 - Comparación y análisis de resultados
#
# En la celda 5 comparen los resultados obtenidos de los diferentes modelos y comenten cómo el preprocesamiento de texto afecta el desempeño.

# %%
# Celda 5 Código para graficos y tablas comparativas
# Celda 5: Comparación de resultados

resultados = pd.DataFrame({
    'Modelo': [
        'CountVectorizer raw (unigrams)',
        'CountVectorizer (unigrams)',
        'CountVectorizer (trigrams)',
        'TF‑IDF (unigrams)'
    ],
    'MSE': [
        mse_raw,
        mse_clean,
        mse_tri,
        mse_tfidf
    ]
})

resultados.sort_values(by='MSE', ascending=True, inplace=True)
print(resultados)

# 3) Gráfico de barras

fig, ax = plt.subplots(figsize=(10, 6))
bars = ax.bar(resultados['Modelo'], resultados['MSE'])
ax.set_xticklabels(resultados['Modelo'], rotation=45, ha='right')
for bar in bars:
    height = bar.get_height()
    ax.text(
        x=bar.get_x() + bar.get_width() / 2,  
        y=height,                             
        s=f"{height:.4f}",                    
        ha='center',                          
        va='bottom'                           
    )
ax.set_ylabel('MSE')
ax.set_title('Comparación de MSE Modelos')
plt.tight_layout()
plt.show()
# Out:
#                            Modelo       MSE
# 3               TF‑IDF (unigrams)  0.030961
# 0  CountVectorizer raw (unigrams)  0.030998
# 1      CountVectorizer (unigrams)  0.031161
# 2      CountVectorizer (trigrams)  0.037325

# %% [markdown]
# ### Punto 5.1 - Comparación y análisis de resultados
# | Modelo                              | MSE      | Comentario                                                                                                                                          |
# |-------------------------------------|----------|-----------------------------------------------------------------------------------------------------------------------------------------------------|
# | TF‑IDF (unigrams)                   | 0.030961 | Mejor performance: La ponderación de las palabras ayuda a mejorar el rendimiento.            |
# | CountVectorizer raw (unigrams)      | 0.030998 | Sin el preprocesamiento se estan teniendo en cuenta todos los tokens. Deben existir algunos tokens particulares que aportan información al modelo y deben estar inlcuiods             |
# | CountVectorizer (unigrams)          | 0.031161 | El desempeño es bueno, sin embargo, al hacer el preprocesamiento se han eliminado tokens que tienen información importante para la predicción del modelo. Deben ser tokens que pueden ser confundidos como stopwords facilmente |
# | CountVectorizer (trigrams)          | 0.037325 | Los trigramas aumentan demasiado la dimensionalidad del modelo, generando una matriz con bastantes ceros. El modelo no logra generalizar bien debido a esta cantidad de información poco útil para predecir        |
#
#
# En general, el preprocesamiento de los textos puede ayudar o puede empeorar los modelos al eliminar palabras que pueden o no aportar significativamente. Es necesario hacer la limpieza muy cuidadosamente para asegurar que el modelo va a tener buen desempeño
