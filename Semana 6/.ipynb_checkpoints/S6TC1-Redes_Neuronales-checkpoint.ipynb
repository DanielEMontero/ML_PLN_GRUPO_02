# %% [markdown]
# ![image info](https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/images/banner_1.png)

# %% [markdown]
# # Taller: Redes Neuronales
#
# En este taller podrán poner en práctica sus conocimientos sobre la construcción e implementación de redes neuronales de una capa y multicapa. El taller está constituido por 4 puntos, en los cuales deberan seguir las intrucciones de cada numeral para su desarrollo.

# %% [markdown]
# ## Datos predicción probabilidad de admisión a la universidad
#
# En este taller se usará el conjunto de datos de admisiones a una universidad proveniente de la base de datos de Kaggle. Cada observación contiene la probabilidad de que un estudiante sea admitido por la universidad, dadas distintas variables predictoras como el puntaje del examén TOEFL y GRE, el promedio (GPA), entre otras. El objetivo es predecir la probabilidad de admissión de cada estudiante. Para más detalles pueden visitar el siguiente enlace: [datos](https://www.kaggle.com/mohansacharya/graduate-admissions).

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
# Importación librerías
import numpy as np
import keras 
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

import tensorflow as tf
from keras import backend as K
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_absolute_error, mean_squared_error
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import Dropout
from keras.callbacks import EarlyStopping
from livelossplot import PlotLossesKeras
from keras.layers import Activation

# %%
# Carga de datos de archivo .csv
data = pd.read_csv('https://raw.githubusercontent.com/albahnsen/MIAD_ML_and_NLP/main/datasets/universityGraduateAdmissions.csv', index_col=0)
data.head()
# Out:
#             GRE Score  TOEFL Score  University Rating  SOP  LOR   CGPA  \
# Serial No.
# 1                 337          118                  4  4.5   4.5  9.65
# 2                 324          107                  4  4.0   4.5  8.87
# 3                 316          104                  3  3.0   3.5  8.00
# 4                 322          110                  3  3.5   2.5  8.67
# 5                 314          103                  2  2.0   3.0  8.21
#
#             Research  Chance of Admit
# Serial No.
# 1                  1              0.92
# 2                  1              0.76
# 3                  1              0.72
# 4                  1              0.80
# 5                  0              0.65

# %%
data.describe()
# Out:
#         GRE Score  TOEFL Score  University Rating         SOP       LOR   \
# count  500.000000   500.000000         500.000000  500.000000  500.00000
# mean   316.472000   107.192000           3.114000    3.374000    3.48400
# std     11.295148     6.081868           1.143512    0.991004    0.92545
# min    290.000000    92.000000           1.000000    1.000000    1.00000
# 25%    308.000000   103.000000           2.000000    2.500000    3.00000
# 50%    317.000000   107.000000           3.000000    3.500000    3.50000
# 75%    325.000000   112.000000           4.000000    4.000000    4.00000
# max    340.000000   120.000000           5.000000    5.000000    5.00000
#
#              CGPA    Research  Chance of Admit
# count  500.000000  500.000000         500.00000
# mean     8.576440    0.560000           0.72174
# std      0.604813    0.496884           0.14114
# min      6.800000    0.000000           0.34000
# 25%      8.127500    0.000000           0.63000
# 50%      8.560000    1.000000           0.72000
# 75%      9.040000    1.000000           0.82000
# max      9.920000    1.000000           0.97000

# %%
# Hitogramas de las varaibles del dataset
data.hist(bins=25, figsize=(15,15))
plt.show()

# %%
# Definición de variables predictoras (X)
X = data.drop(data.columns[-1], axis=1)
# Definición de variable de interés (y)
Y = data[data.columns[-1]]

# %%
# Separación de variables predictoras (X) y variable de interés (y) en set de entrenamiento y test usandola función train_test_split
xTrain, xTest, yTrain, yTest = train_test_split(X,Y,test_size=0.3, random_state=22)

# %%
# Normalización de variables predictoras (X) con la función StandardScaler
# Definición de la función StandardScaler
scaler = StandardScaler()
scaler.fit(X)

# Transformación de los set de entrenamiento y test
xTrain = pd.DataFrame(data=scaler.transform(xTrain), columns=xTrain.columns, index=xTrain.index)
xTest = pd.DataFrame(data=scaler.transform(xTest), columns=xTest.columns, index=xTest.index)

xTrain = np.array(xTrain)
yTrain = np.array(yTrain).reshape(-1,1)

xTest = np.array(xTest)
yTest = np.array(yTest).reshape(-1,1)

# %% [markdown]
# ## Punto 1 - Red Neuronal de una capa
#
# En la celda 1 creen una **red neuronal de una capa** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes, usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador y el número de épocas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 1
output_var = yTrain.shape[1]
dims = xTrain.shape[1]
K.clear_session()
model = Sequential()
model.add(Dense(output_var, input_shape=(dims,)))
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 1)              │             8 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 8 (32.00 B)
#  Trainable params: 8 (32.00 B)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de función de perdida. Se usa mean_squared_error dado que es un ejercicio de regresión
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
model.fit(xTrain, yTrain, 
          verbose=1, 
          epochs=50, 
          validation_data=(xTest, yTest),
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.004, max:    0.589, cur:    0.004)
# 	validation       	 (min:    0.004, max:    0.501, cur:    0.004)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0040 - val_loss: 0.0035

# %% [markdown]
# ### Selección de hiperparametros:
#
# - Función de pérdida: debido a la ausencia de valores atípicos que puedan afectar el modelo, así como la búsqueda de penalización de errores grandes, se elige como función de pérdida el 'mean_squared_error'
# - Optimizador: Debido a su buen desempeño en modelos menos complejos y su eficiencia en términos computacionales, se decide trabajar con el optimizados sgd.
# - Número de Epocas: Debido al comportamiento de la función de pérdida para 50 épocas, se concluye que son suficientes para entender la convergencia del modelo

# %%
y_pred_train = model.predict(xTrain)
y_pred_test = model.predict(xTest)

mse_una_capa_train = mean_squared_error(yTrain, y_pred_train)
mae_una_capa_train = mean_absolute_error(yTrain, y_pred_train)

mse_una_capa_test = mean_squared_error(yTest, y_pred_test)
mae_una_capa_test = mean_absolute_error(yTest, y_pred_test)

print(f'Mean Squared Error (MSE) red neuronal de una capa (TRAIN): {mse_una_capa_train}')
print(f'Mean Absolute Error (MAE) red neuronal de una capa (TRAIN): {mae_una_capa_train}')
print(f'Mean Squared Error (MSE) red neuronal de una capa (TEST): {mse_una_capa_test}')
print(f'Mean Absolute Error (MAE) red neuronal de una capa (TEST): {mae_una_capa_test}')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Mean Squared Error (MSE) red neuronal de una capa (TRAIN): 0.004070545739250938
# Mean Absolute Error (MAE) red neuronal de una capa (TRAIN): 0.04576497874941145
# Mean Squared Error (MSE) red neuronal de una capa (TEST): 0.0035259647096482624
# Mean Absolute Error (MAE) red neuronal de una capa (TEST): 0.043818379672368374

# %% [markdown]
# ## Punto 2 - Red Neuronal multicapa
#
# En la celda 2 creen una **red neuronal con dos capas** con la librería Keras, que prediga la probabilidad de admisión de los estudiantes usando los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 2
# Definición de dimensiones de salida, varaibles de interés
output_var = yTrain.shape[1]
print(output_var, ' output variables')

# Definición de dimensiones de entrada, varaibles predictoras
dims = xTrain.shape[1]
print(dims, 'input variables')
# Out:
# 1  output variables
# 7 input variables

# %%
K.clear_session()

# Definición red neuronal con la función Sequential()
model = Sequential()
model.add(Dense(256, input_shape=(dims,), activation='relu'))
model.add(Dense(256, activation='relu'))          
model.add(Dense(output_var))
model.add(Activation('relu'))


# Impresión de la arquitectura de la red neuronal
print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           257 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ activation (Activation)         │ (None, 1)              │             0 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,097 (266.00 KB)
#  Trainable params: 68,097 (266.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
# Definición de la función de optimización
model.compile(optimizer='sgd',
              loss='mean_squared_error')

# %%
# Entrenamiento de la red neuronal con 50 épocas
model.fit(xTrain, yTrain, 
          verbose=1, 
          epochs=50, 
          validation_data=(xTest, yTest),
          callbacks=[PlotLossesKeras()])
# Out:
# Loss
# 	training         	 (min:    0.005, max:    0.194, cur:    0.005)
# 	validation       	 (min:    0.006, max:    0.078, cur:    0.006)
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 31ms/step - loss: 0.0040 - val_loss: 0.0060

# %% [markdown]
# - Función de pérdida: debido a la ausencia de valores atípicos que puedan afectar el modelo, así como la búsqueda de penalización de errores grandes, se elige como función de pérdida el 'mean_squared_error'
# - Función de activación: Se selecciona Relu ya que comparada a las funciones tanh(x) y sigmodiea es mucha más fácil de procesar.
# - Optimizador: Debido a su buen desempeño en modelos menos complejos y su eficiencia en términos computacionales, se decide trabajar con el optimizador sgd.
# - Número de Epocas: Debido al comportamiento de la función de pérdida para 50 épocas, se concluye que son suficientes para entender la convergencia del modelo
# - Número de neuronas en las capas: Para este caso en particular, se usaron 256 neuronas en cada capa debido a que la capacidad de predicción mejora.

# %%
yPredTrain = model.predict(xTrain)
yPredTest  = model.predict(xTest)

mae_multicapa_train = mean_absolute_error(yTrain, yPredTrain)
mse_multicapa_train = mean_squared_error(yTrain, yPredTrain)

mae_multicapa_test  = mean_absolute_error(yTest,  yPredTest)
mse_multicapa_test  = mean_squared_error(yTest,  yPredTest)

# Impresión en el formato solicitado
print(f'Mean Squared Error (MSE) red neuronal multicapa (TRAIN): {mse_multicapa_train:.4f}')
print(f'Mean Absolute Error (MAE) red neuronal multicapa (TRAIN): {mae_multicapa_train:.4f}')
print(f'Mean Squared Error (MSE) red neuronal multicapa (TEST): {mse_multicapa_test:.4f}')
print(f'Mean Absolute Error (MAE) red neuronal multicapa (TEST): {mae_multicapa_test:.4f}')
# Out:
# 11/11 ━━━━━━━━━━━━━━━━━━━━ 0s 8ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 7ms/step
# Mean Squared Error (MSE) red neuronal multicapa (TRAIN): 0.0048
# Mean Absolute Error (MAE) red neuronal multicapa (TRAIN): 0.0549
# Mean Squared Error (MSE) red neuronal multicapa (TEST): 0.0060
# Mean Absolute Error (MAE) red neuronal multicapa (TEST): 0.0614

# %% [markdown]
# ## Punto 3  - Red Neuronal multicapa
#
# En la celda 3 creen **una red neuronal con más de una capa con la librería Keras, usando early stopping y dropout,** que prediga la probabilidad de admisión de los estudiantes con los sets de entrenamiento y test definidos anteriormente. Pueden usar la función de perdida, el optimizador, el número de épocas y el número de neuronas que consideren pertinentes para el modelo, justificando su selección. Finalmente, grafiquen la pérdida del modelo vs el número de épocas en el set de entrenamiento y validación, y presenten el desempeño del modelo con las métricas error absoluto medio (MAE) y error cuadrático medio (MSE).

# %%
# Celda 3
K.clear_session()

model = Sequential()
model.add(Dense(256, activation='relu', input_shape=(xTrain.shape[1],)))
model.add(Dropout(0.3))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid'))

print(model.summary())
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 256)            │         2,048 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │        65,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │           257 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 68,097 (266.00 KB)
#  Trainable params: 68,097 (266.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
model.compile(optimizer='sgd', loss='mse', metrics=['mae'])
early_stop=EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)

# %%
X_train, X_val, Y_train, Y_val = train_test_split(xTrain, yTrain, test_size=0.15, random_state=42)

# %%
modelo=model.fit(X_train, Y_train,
          validation_data=(X_val, Y_val),
          epochs=100,
          callbacks=[early_stop])
modelo
# Out:
# Epoch 1/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 53ms/step - loss: 0.0516 - mae: 0.2002 - val_loss: 0.0534 - val_mae: 0.2085
# Epoch 2/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 26ms/step - loss: 0.0409 - mae: 0.1762 - val_loss: 0.0485 - val_mae: 0.1993
# Epoch 3/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 23ms/step - loss: 0.0410 - mae: 0.1781 - val_loss: 0.0440 - val_mae: 0.1906
# Epoch 4/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 25ms/step - loss: 0.0396 - mae: 0.1742 - val_loss: 0.0400 - val_mae: 0.1824
# Epoch 5/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 30ms/step - loss: 0.0353 - mae: 0.1654 - val_loss: 0.0365 - val_mae: 0.1747
# Epoch 6/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - loss: 0.
# Epoch 92/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0069 - mae: 0.0621 - val_loss: 0.0055 - val_mae: 0.0571
# Epoch 93/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0071 - mae: 0.0646 - val_loss: 0.0055 - val_mae: 0.0570
# Epoch 94/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0070 - mae: 0.0626 - val_loss: 0.0055 - val_mae: 0.0568
# Epoch 95/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0070 - mae: 0.0646 - val_loss: 0.0055 - val_mae: 0.0566
# Epoch 96/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - loss: 0.0081 - mae: 0.0675 - val_loss: 0.0054 - val_mae: 0.0564
# Epoch 97/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0060 - mae: 0.0593 - val_loss: 0.0054 - val_mae: 0.0563
# Epoch 98/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - loss: 0.0076 - mae: 0.0648 - val_loss: 0.0054 - val_mae: 0.0561
# Epoch 99/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - loss: 0.0073 - mae: 0.0660 - val_loss: 0.0054 - val_mae: 0.0559
# Epoch 100/100
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - loss: 0.0078 - mae: 0.0663 - val_loss: 0.0054 - val_mae: 0.0558

# %% [markdown]
# Se ha decidido poner dos capas densas, con lo requerido del dropout y el early stop, el cual tiene un tiempo de espera donde el modelo no mejora de 10, ya que con 2, como se planteó en el laboratorio, este se detenía muy rápido sin casi mostrar las épocas. Por consiguiente, se configuró así para alargar las épocas mostradas y que posteriormente en la gráfica se visualizará mejor. De igual manera, no se usó 'relu' en la capa de salida, ya que esta es más adecuada para resultados de 0 a infinito, mientras que 'sigmoid' es mejor para valores acotados entre 0 y 1.

# %%
plt.plot(modelo.history['loss'], label='Pérdida Entrenamiento')
plt.plot(modelo.history['val_loss'], label='Pérdida Validación')
plt.xlabel('Épocas')
plt.ylabel('Pérdida (MSE)')
plt.title('Pérdida vs Épocas')
plt.legend()
plt.grid(True)
plt.show()

# %% [markdown]
# El modelo muestra un buen aprendizaje a lo largo de las épocas, ya que ambas pérdidas disminuyen progresivamente como se espera. Tambien, no se evidencia overfitting, pues la pérdida de validación sigue una tendencia similar a la de entrenamiento.

# %%
y_pred_test=model.predict(X_val).flatten()
y_pred_train=model.predict(X_train).flatten()

mae_train=mean_absolute_error(Y_train, y_pred_train)
mse_train=mean_squared_error(Y_train, y_pred_train)

mae_test=mean_absolute_error(Y_val, y_pred_test)
mse_test=mean_squared_error(Y_val, y_pred_test)

print("MAE_tain: ", mae_train)
print("MSE_train: ", mse_train)

print("MAE_test: ", mae_test)
print("MSE_test: ", mse_test)
# Out:
# 2/2 ━━━━━━━━━━━━━━━━━━━━ 0s 150ms/step
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step
# MAE_tain:  0.056407397459653084
# MSE_train:  0.005601441049448958
# MAE_test:  0.05576547537209853
# MSE_test:  0.005397052147671665

# %% [markdown]
# Los valores del MSE y MAE, son bastante bajas, por lo que el modelo está haciendo predicciones bastante acercadas a los valores reales.

# %% [markdown]
# ## Punto 4 - Comparación y análisis de resultados
#
# En la celda 4 comparen los resultados obtenidos de las diferentes redes y comenten las ventajas del mejor modelo y las desventajas del modelo con el menor desempeño.

# %%
# Celda 4
labels = ['una capa','Multi capa','Multi capa 2']
mse_values = [mse_una_capa_test, mse_multicapa_test, mse_test]

labels_sorted, accuracy_values = zip(*sorted(zip(labels, mse_values), key=lambda x: x[1], reverse=True))


plt.figure(figsize=(14, 6))
bars = plt.bar(labels_sorted, accuracy_values, color='skyblue')
plt.xticks(rotation=45, ha='right')
plt.ylabel('MSE en test')
plt.title('Comparación MSE redes neuronales')
plt.grid(axis='y', linestyle='--', alpha=0.6)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval , f'{yval:.4f}', ha='center', va='bottom')

plt.tight_layout()
plt.show()

# %% [markdown]
# **Ventajas modelo mono capa**
# - Como el dataset no presetna complejidad en lo datos y además hay relaciones lineales entre los datos, el modelo de una sola capa tiene un buen poder predictivo para este tipo de relaciones. Además, al ser un modelo de pocas neuronas es rápido y sencillo de entrenar y desplegar.
#
# **Desventajas modelo multicapa**
# - Por otro lado, el modelo multicapa complejiza al tener 2 capas de 256 neuronas cada una, agregando trasnformaciones extras para un conjunto de datos, que según los resultados, resulta ser innecesarias. Además, su implementación es más compleja frente el mono capa y esa complejidad no se transfroma en un mejor desempeño.
